# %%
import os
import sys
module_path = os.path.abspath(os.path.expanduser("~/notebooks/geospatial/"))
# print(f"Module path is {module_path}")
# print(f"Sys path is {sys.path}")
if module_path not in sys.path:
    print("$$$$$$$$")
    sys.path.append(module_path)

from sar.benchmarks.profiler import Profiler
from sar.processing import apply_window_filter
from sar.filters.refined_lee import refined_lee_filter

with Profiler():

    filtered = apply_window_filter(
        image=pre,
        filter_function=refined_lee_filter,
        window_size=7,
    )
# Out:
# ============================================================
# Elapsed Time : 0.00 seconds
# ============================================================
#          2 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/notebooks/geospatial/sar/benchmarks/profiler.py:35(__exit__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 17
#      12 from sar.filters.refined_lee import refined_lee_filter
#      14 with Profiler():
#      16     filtered = apply_window_filter(
# ---> 17         image=pre,
#      18         filter_function=refined_lee_filter,
#      19         window_size=7,
#      20     )
#
# NameError: name 'pre' is not defined
